# %% [markdown]
# # String Operations

# %% [raw]
# '',"",""""""

# %% [raw]
# Sequence of character enclosded in a '',"","""""": (ordered, immutable)

# %%
name='ramoji'
address =""" Flat no 24,
hyderabad,
Telangana
pin :500089

"""

# %%
print(name)
print(address)
# Out:
# ramoji
#  Flat no 24,
# hyderabad,
# Telangana
# pin :500089

# %%
city="Tanuku sadfasdfsa"

# %%
print(city)
# Out:
# Tanuku sadfasdfsa

# %%
email="ramojira999@gmail.com"

# %%
Website ="WWW.google.com"

# %%
print(Website,email)
# Out:
# WWW.google.com ramojira999@gmail.com

# %% [markdown]
# # String properties

# %%
name = "Python"

# %% [raw]
# p  y  t  h  o  n
# 0  1  2  3  4  5 # Postive index
# -6 -5 -4 -3 -2 -1 # Negative Index

# %%
print(name[0],name[4], name[-3])
# Out:
# P o h

# %% [markdown]
# # Length of string

# %%
#len()
name = "Python Programming"
print(len(name))
# Out:
# 18

# %% [markdown]
# # String Slicing

# %%
# String[start:stop:step]
text = "Programming language Python"
print(text)
# Out:
# Programming language Python

# %%
print(len(text))
# Out:
# 27

# %%
print(text[0:27:1])
# Out:
# Programming language Python

# %%
print(text[0:27:2])
# Out:
# Pormiglnug yhn

# %%
print(text[21:27])
# Out:
# Python

# %%
print(text[:11])
# Out:
# Programming

# %%
print(text[12:])
# Out:
# language Python

# %%
print(text[::])
# Out:
# Programming language Python

# %%
print(text[:])
# Out:
# Programming language Python

# %%
print(text[::-1])
# Out:
# nohtyP egaugnal gnimmargorP

# %%
# Palandrom "madam"
text="good"
print(text[::-1])
# Out:
# doog

# %% [markdown]
# # String Operators

# %%
first = "Ramoji"
Second = "Yalamati"

print(first + Second)
# Out:
# RamojiYalamati

# %%
print(first * 3)
# Out:
# RamojiRamojiRamoji

# %% [markdown]
# # Member ship

# %%
language = "Python"
print("Py" in language)
# Out:
# True

# %% [markdown]
# # String Traversing

# %%
# using for loop or While loop
name = "Ramoji"
        #012345    
#len(name) length of sting
# while <condition>
# name[i] retriving element using index
# increment i value
i=0
print(len(name))
while i<len(name):
    print(f"{i} th index value is :{name[i]}")
    i += 1
# Out:
# 6
# 0 th index value is :R
# 1 th index value is :a
# 2 th index value is :m
# 3 th index value is :o
# 4 th index value is :j
# 5 th index value is :i

# %% [markdown]
# # same opertion using for loop Task2

# %% [markdown]
# # emumerate

# %%
enumerate("python")

# %%
print(enumerate)
# Out:
# <class 'enumerate'>

# %%
for index,value in enumerate("python"):
    print(index,value)
# Out:
# 0 p
# 1 y
# 2 t
# 3 h
# 4 o
# 5 n

# %% [markdown]
# # Escape Sequence in String

# %%
print("hello\n world")
# Out:
# hello
#  world

# %%
print("hello\tworld")
# Out:
# hello	world

# %%
print("D:\CODING\Training\Python")
# Out:
# D:\CODING\Training\Python

# %%
print("he said \"hello\"")
# Out:
# he said "hello"

# %%
"ramoji "yalamati""
# Out:
#   Cell In[52], line 1
#     "ramoji "yalamati""
#              ^
# SyntaxError: invalid syntax

# %%
"ramoji\"yalamati\""
# Out:
# 'ramoji"yalamati"'

# %% [markdown]
# # String Methods

# %% [markdown]
# upper()
# lower()
# title()
# capitalize()
# swapcase()
# casefold()

# %%
name="ramoji"

print(name.upper(),name.lower(),name.title(),name.capitalize(),name.swapcase(),name.casefold(),sep='\n',)
# Out:
# RAMOJI
# ramoji
# Ramoji
# Ramoji
# RAMOJI
# ramoji

# %% [markdown]
# # Validation methods

# %% [raw]
# isalpha()
# isdigit()
# isalnum()
# islower()
# isupper()
# isspace()
# istitle()
# isdecimal()
# isnumeric()
# isidentifier()

# %% [markdown]
# # Password validation

# %%
while True:
    pin = input()
    if pin.isdigit() and len(pin)==4:
        print("valid pin")
        break
    else:
        print("invalid pin")
# Out:
#  123c
# invalid pin
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 2
#       1 while True:
# ----> 2     pin = input()
#       3     if pin.isdigit() and len(pin)==4:
#       4         print("valid pin")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
# ...
