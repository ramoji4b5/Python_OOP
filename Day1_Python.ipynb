# %%
print("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# # 1991 Guido van Rossum

# %% [markdown]
# Easy to Learn
# Easy to Read
# Less coding
# Huge comminity
# Thousands of libraries
# Cross -platform
# Excellent for AI & Data Sciencen Applcations

# %% [markdown]
# # C language

# %% [raw]
# #include<stdio.h>
# int main()
# {
#     printf("hello");
# return 0;
# }

# %% [markdown]
# # Java

# %% [raw]
# public Static void main(String args[])
# {
#     System.out.println("hello");
# }

# %%
print("hello")
# Out:
# hello

# %%
age =25

# %%
type(age)
# Out:
# int

# %%
name="Ramoji"

# %%
type(name)
# Out:
# str

# %%
int age =35;
string name = "ramoji";

# %% [markdown]
# # look like simple English

# %%
marks = 40
if marks > 35:
    print("pass")
# Out:
# pass

# %% [markdown]
# # Platform Indepenent

# %% [raw]
# microsoft window
# Linux/CentOS/Ubuntu --> Kernel Operating system
# Mac OS --> apple operating system

# %% [markdown]
# # Large Library Base

# %% [raw]
# math
# OS
# csv,pdf,
# Pands,Numpy
# Mathplotlib,ploty
# Scikit-learn
# Tensorflow,Pytorch
# NLTK,Spacy
# langchain,LlamaIndex,
# Django,Flask,FastAPI
# Selenium-python
# boto3,google-cloud-sdk

# %% [markdown]
# ## Where Python is Used ?

# %% [raw]
# 1. Web Application
# 2. Data Science Application.
# 3. AI Application
# 4. Machine Learning application.
# 5. Cloud
# 6. Automations
# 7. Cyber Security
# 8. DevOps ( CI/CD)
# 9. IoT ( Internet of things)
# 10 Game Development

# %% [markdown]
# # Which Organization Using Python ?

# %% [raw]
# Google.
# Netflix.
# Instagram
# Spotify
# Uber
# Amazon
# Mircosoft
